# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/churn_sintetico.csv")

df.head()
# Out:
#    tenure_months  monthly_charge  total_charges  support_tickets  \
# 0              7           58.23         326.50                2
# 1             56           56.75        3154.21                0
# 2             48           78.84        3864.31                3
# 3             32           79.74        2511.40                0
# 4             32           55.37        1735.51                3
#
#    late_payments  avg_monthly_usage_gb contract_type payment_method  \
# 0              1                 81.83       mensual  transferencia
# 1              2                 96.52         anual         debito
# 2              2                 93.60       bianual       efectivo
# 3              0                 28.95       bianual         debito
# 4              0                126.90         anual       efectivo
#
#   internet_service  has_streaming  has_security_pack  num_products  region  \
# 0            cable              0                  1             3  centro
# 1            fibra              0                  0             4  centro
# 2            movil              1                  1             4  centro
# 3            movil              0                  1             4   norte
# 4            fibra              1                  0             2   oeste
#
#    customer_age  is_promo  churn
# 0            53         1      1
# 1            53         0      0
# 2            73         1      1
# 3            25         0      1
# 4            61         1      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tenure_months         5000 non-null   int64
#  1   monthly_charge        5000 non-null   float64
#  2   total_charges         5000 non-null   float64
#  3   support_tickets       5000 non-null   int64
#  4   late_payments         5000 non-null   int64
#  5   avg_monthly_usage_gb  5000 non-null   float64
#  6   contract_type         5000 non-null   object
#  7   payment_method        5000 non-null   object
#  8   internet_service      5000 non-null   object
#  9   has_streaming         5000 non-null   int64
#  10  has_security_pack     5000 non-null   int64
#  11  num_products          5000 non-null   int64
#  12  region                5000 non-null   object
#  13  customer_age          5000 non-null   int64
#  14  is_promo              5000 non-null   int64
#  15  churn                 5000 non-null   int64
# dtypes: float64(3), int64(9), object(4)
# memory usage: 625.1+ KB

# %%
df.describe(include="all")
# Out:
#         tenure_months  monthly_charge  total_charges  support_tickets  \
# count     5000.000000     5000.000000    5000.000000      5000.000000
# unique            NaN             NaN            NaN              NaN
# top               NaN             NaN            NaN              NaN
# freq              NaN             NaN            NaN              NaN
# mean        36.407200       65.273282    2371.156582         1.710400
# std         20.839776       17.963425    1555.943231         1.304788
# min          1.000000       15.000000      50.000000         0.000000
# 25%         18.000000       53.060000    1100.357500         1.000000
# 50%         36.000000       64.965000    2162.810000         2.000000
# 75%         55.000000       77.362500    3432.657500         2.000000
# max         72.000000      127.170000    9083.060000         8.000000
#
#         late_payments  avg_monthly_usage_gb contract_type payment_method  \
# count      5000.00000           5000.000000          5000           5000
# unique            NaN                   NaN             3              4
# top               NaN                   NaN       mensual         debito
# freq              NaN                   NaN          2750           1751
# mean          0.69700            120.528458           NaN            NaN
# std           0.84388             49.745297           NaN            NaN
# min           0.00000              5.000000           NaN            NaN
# 25%           0.00000             86.505000           NaN            NaN
# 50%           0.00000            120.030000           NaN            NaN
# 75%           1.00000            154.100000           NaN            NaN
# max           5.00000            324.400000           NaN            NaN
#
#        internet_service  has_streaming  has_security_pack  num_products  \
# count              5000    5000.000000        5000.000000   5000.000000
# unique                4            NaN                NaN           NaN
# top               fibra            NaN                NaN           NaN
# freq               2240            NaN                NaN           NaN
# mean                NaN       0.668000           0.539800      2.516400
# std                 NaN       0.470978           0.498463      1.111746
# min                 NaN       0.000000           0.000000      1.000000
# 25%                 NaN       0.000000           0.000000      2.000000
# 50%                 NaN       1.000000           1.000000      3.000000
# 75%                 NaN       1.000000           1.000000      4.000000
# max                 NaN       1.000000           1.000000      4.000000
#
#         region  customer_age     is_promo        churn
# count     5000   5000.000000  5000.000000  5000.000000
# unique       4           NaN          NaN          NaN
# top     centro           NaN          NaN          NaN
# freq      1818           NaN          NaN          NaN
# mean       NaN     47.825800     0.386200     0.340400
# std        NaN     17.615684     0.486926     0.473891
# min        NaN     18.000000     0.000000     0.000000
# 25%        NaN     32.000000     0.000000     0.000000
# 50%        NaN     48.000000     0.000000     0.000000
# 75%        NaN     63.000000     1.000000     1.000000
# max        NaN     78.000000     1.000000     1.000000

# %%
df["churn"].value_counts()
# Out:
# churn
# 0    3298
# 1    1702
# Name: count, dtype: int64

# %%
sns.countplot(x="churn", data=df)
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns

df[numeric_cols].hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.show()
